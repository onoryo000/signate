# %%
import pandas as pd
import numpy as np
import math
import unicodedata

import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
n = (train.state.unique()[0])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27532 entries, 0 to 27531
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            27532 non-null  int64
#  1   region        27532 non-null  object
#  2   year          27532 non-null  int64
#  3   manufacturer  27532 non-null  object
#  4   condition     27532 non-null  object
#  5   cylinders     27532 non-null  object
#  6   fuel          26293 non-null  object
#  7   odometer      27532 non-null  int64
#  8   title_status  27076 non-null  object
#  9   transmission  27532 non-null  object
#  10  drive         27532 non-null  object
#  11  size          27532 non-null  object
#  12  type          27076 non-null  object
#  13  paint_color   27532 non-null  object
#  14  state         24228 non-null  object
#  15  price         27532 non-null  int64
# dtypes: int64(4), object(12)
# memory usage: 3.4+ MB

# %%
train.describe(include="O")
# Out:
#             region manufacturer  condition    cylinders   fuel title_status  \
# count        27532        27532      27532        27532  26293        27076
# unique         372          125          6            8      5            6
# top     central NJ         ford  excellent  6 cylinders    gas        clean
# freq          1069         6166      15219        11504  23546        22365
#
#        transmission  drive       size   type paint_color  state
# count         27532  27532      27532  27076       27532  24228
# unique            3      3          9     13          12     51
# top       automatic    fwd  full-size  sedan       black     ca
# freq          20497  14602      14585   9259       10143   2702

# %%
train.describe()
# Out:
#                  id          year      odometer         price
# count  27532.000000  27532.000000  2.753200e+04  27532.000000
# mean   13765.500000   2007.832958  1.160199e+05  13468.724829
# std     7947.948142     15.758976  6.451642e+04  10962.149840
# min        0.000000   1921.000000 -1.318690e+05   1004.000000
# 25%     6882.750000   2005.000000  7.836775e+04   5759.000000
# 50%    13765.500000   2011.000000  1.114445e+05   9206.000000
# 75%    20648.250000   2014.000000  1.508562e+05  19128.000000
# max    27531.000000   3017.000000  2.946000e+06  96818.000000

# %%
train['size'] = train['size'].str.replace('full-size', 'fullsize').replace('fullーsize', 'fullsize').replace('full−size', 'fullsize').replace('mid-size', 'midsize').replace('midーsize', 'midsize').replace('mid−size', 'midsize').replace('sub-compact','subcompact').replace('subーcompact', 'subcompact')
test['size'] = test['size'].str.replace('full-size', 'fullsize').replace('fullーsize', 'fullsize').replace('full−size', 'fullsize').replace('mid-size', 'midsize').replace('midーsize', 'midsize').replace('mid−size', 'midsize').replace('sub-compact','subcompact').replace('subーcompact', 'subcompact')

# %%
def to_half_width(text):
    return ''.join([unicodedata.normalize('NFKC', char).lower().replace("а", "a").replace("ѕ", "s").replace("о", "o").replace("α", "a") for char in text])

train["manufacturer"] = train["manufacturer"].apply(to_half_width)
test["manufacturer"] = test["manufacturer"].apply(to_half_width)

# %%
train.describe(include="O")
# Out:
#             region manufacturer  condition    cylinders   fuel title_status  \
# count        27532        27532      27532        27532  26293        27076
# unique         372           38          6            8      5            6
# top     central NJ         ford  excellent  6 cylinders    gas        clean
# freq          1069         6943      15219        11504  23546        22365
#
#        transmission  drive      size   type paint_color  state
# count         27532  27532     27532  27076       27532  24228
# unique            3      3         4     13          12     51
# top       automatic    fwd  fullsize  sedan       black     ca
# freq          20497  14602     14636   9259       10143   2702

# %%
train.condition.unique()
# Out:
# array(['excellent', 'fair', 'good', 'like new', 'salvage', 'new'],
#       dtype=object)

# %%
conmap = {"salvage": 0, "fair": 1, "good": 2, "excellent": 3, "like_new": 4, "new": 5}
train["condition"] = train.condition.map(conmap)
test["condition"] = test.condition.map(conmap)


cylmap = {'6 cylinders': 6, '8 cylinders': 8, '4 cylinders': 4, 'other': n,
       '10 cylinders': 10, '12 cylinders': 12, '5 cylinders': 5, '3 cylinders': 3}
train["cylinders"] = train.cylinders.map(cylmap)
test["cylinders"] = test.cylinders.map(cylmap)

# %%
train = train.fillna({"cylinders": train.cylinders.mean()})
test = test.fillna({"cylinders": train.cylinders.mean()})

# %%
l = {"dc": [9856, 68], "nj": [1195, 8722], "ri": [1018, 1544], "ma": [839, 10554], "ct": [738, 5543],
     "md": [594, 12405], "de": [460, 2488], "ny": [4141, 54554], "fl": [350, 65757], "pa": [282, 46054],
     "oh": [282, 44825], "ca": [239, 163694], "il": [231, 57913], "hi": [211, 10931], "va": [202, 42774],
     "nc": [196, 53819], "in": [180, 36419], "mi": [174, 96713], "ga": [168, 59425], "tn": [153, 42144],
     "sc": [153, 32020], "nh": [147, 9346], "ky": [109, 40407], "wi": [105, 65496], "la": [104, 52378],
     "wa": [101, 71297], "tx": [96, 268596], "al": [94, 52420], "mo": [87, 69706], "wv": [77, 24230],
     "vt": [67, 9616], "mn": [66, 86935], "ms": [63, 48431], "az": [56, 113990], "ar": [56, 53178],
     "ok": [54, 69898], "ia": [54, 56272], "co": [48, 104093], "me": [43, 35379], "or": [39, 98378],
     "ks": [34, 82278], "ut": [33, 84896], "nv": [24, 110571], "ne": [23, 77347], "id": [18, 83568],
     "nm": [16, 121590], "sd": [10, 77115], "nd": [9, 70698], "mt": [6, 147039], "wy": [5, 97813], "ak": [1, 665384]}

# %%
train['state_pd'] = n
test['state_pd'] = n
for i in range(train.id.shape[0]):
    # print(i)
    if type(train["state"][i]) == str:
        train['state_pd'][i] = l[train.state[i]][0]
        
for i in range(test.id.shape[0]):
    # print(i)
    if type(test.state[i]) == str:
        test.state_pd[i] = l[test.state[i]][0]
    # print(i)
# Out:
# C:\Users\81703\AppData\Local\Temp\ipykernel_17784\1396616915.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['state_pd'][i] = l[train.state[i]][0]
# C:\Users\81703\AppData\Local\Temp\ipykernel_17784\1396616915.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.state_pd[i] = l[test.state[i]][0]

# %%
train['state_area'] = n
test['state_area'] = n
for i in range(train.id.shape[0]):
    # print(i)
    if type(train["state"][i]) == str:
        train['state_area'][i] = l[train.state[i]][1]
        
for i in range(test.id.shape[0]):
    # print(i)
    if type(test.state[i]) == str:
        test.state_area[i] = l[test.state[i]][1]
    # print(i)
# Out:
# C:\Users\81703\AppData\Local\Temp\ipykernel_17784\1757109156.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['state_area'][i] = l[train.state[i]][1]
# C:\Users\81703\AppData\Local\Temp\ipykernel_17784\1757109156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.state_area[i] = l[test.state[i]][1]

# %%
train['state_pop'] = n
test['state_pop'] = n
for i in range(train.id.shape[0]):
    # print(i)
    if type(train["state"][i]) == str:
        train['state_pop'][i] = l[train.state[i]][0] * l[train.state[i]][1]
        
for i in range(test.id.shape[0]):
    # print(i)
    if type(test.state[i]) == str:
        test.state_pop[i] = l[test.state[i]][0] * l[test.state[i]][1]
    # print(i)
# Out:
# C:\Users\81703\AppData\Local\Temp\ipykernel_17784\354599866.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['state_pop'][i] = l[train.state[i]][0] * l[train.state[i]][1]
# C:\Users\81703\AppData\Local\Temp\ipykernel_17784\354599866.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.state_pop[i] = l[test.state[i]][0] * l[test.state[i]][1]

# %%
train["region"] = train["region"].apply(lambda x: x.replace("/", "nn").replace(",", " "))
test["region"] = test["region"].apply(lambda x: x.replace("/", "nn").replace(",", " "))

# %%
test.shape
# Out:
# (27537, 18)

# %%
import category_encoders as ce
# リストの作成
l_list = ["region", "state"]

ce_oe = ce.OrdinalEncoder(cols=l_list,handle_unknown='impute')
#文字を序数に変換
train = ce_oe.fit_transform(train)
test = ce_oe.fit_transform(test)
#値を1の始まりから0の始まりにする
for i in l_list:
    train[i] = train[i] - 1
    test[i] = test[i] - 1

for i in l_list:
    train[i] = train[i].astype("int")
    test[i] = test[i].astype("int")

col = ["condition", "manufacturer", "size", "fuel", "drive", "type", "title_status", "paint_color", "transmission"]
train = pd.get_dummies(train, columns=col)
test = pd.get_dummies(test, columns=col)

# %%
train = train.fillna({"state_pd": train.state_pd.mean()})
test = test.fillna({"state_pd": test.state_pd.mean()})

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27532 entries, 0 to 27531
# Data columns (total 99 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          27532 non-null  int64
#  1   region                      27532 non-null  int32
#  2   year                        27532 non-null  int64
#  3   cylinders                   27532 non-null  float64
#  4   odometer                    27532 non-null  int64
#  5   state                       27532 non-null  int32
#  6   price                       27532 non-null  int64
#  7   state_pd                    27532 non-null  float64
#  8   state_area                  24228 non-null  float64
#  9   state_pop                   24228 non-null  float64
#  10  condition_0.0               27532 non-null  uint8
#  11  condition_1.0               27532 non-null  uint8
#  12  condition_2.0               27532 non-null  uint8
#  13  condition_3.0               27532 non-null  uint8
#  14  condition_5.0               27532 non-null  uint8
#  15  manufacturer_acura          27532 non-null  uint8
#  16  manufacturer_alfa-romeo     27532 non-null  uint8
#  17  manufacturer_aston-martin   27532 non-null  uint8
#  18  manufacturer_audi           27532 non-null  uint8
#  19  manufacturer_bmw            27532 non-null  uint8
#  20  manufacturer_buick          27532 non-null  uint8
#  21  manufacturer_cadillac       27532 non-null  uint8
#  22  manufacturer_chevrolet      27532 non-null  uint8
#  23  manufacturer_chrysler       27532 non-null  uint8
#  24  manufacturer_dodge          27532 non-null  uint8
#  25  manufacturer_fiat           27532 non-null  uint8
#  26  manufacturer_ford           27532 non-null  uint8
#  27  manufacturer_gmc            27532 non-null  uint8
#  28  manufacturer_honda          27532 non-null  uint8
#  29  manufacturer_hyundai        27532 non-null  uint8
#  30  manufacturer_infiniti       27532 non-null  uint8
#  31  manufacturer_jaguar         27532 non-null  uint8
#  32  manufacturer_jeep           27532 non-null  uint8
#  33  manufacturer_kia            27532 non-null  uint8
#  34  manufacturer_land rover     27532 non-null  uint8
#  35  manufacturer_lexus          27532 non-null  uint8
#  36  manufacturer_lincoln        27532 non-null  uint8
#  37  manufacturer_mazda          27532 non-null  uint8
#  38  manufacturer_mercedes-benz  27532 non-null  uint8
#  39  manufacturer_mercury        27532 non-null  uint8
#  40  manufacturer_mini           27532 non-null  uint8
#  41  manufacturer_mitsubishi     27532 non-null  uint8
#  42  manufacturer_nissan         27532 non-null  uint8
#  43  manufacturer_pontiac        27532 non-null  uint8
#  44  manufacturer_porsche        27532 non-null  uint8
#  45  manufacturer_ram            27532 non-null  uint8
#  46  manufacturer_rover          27532 non-null  uint8
#  47  manufacturer_saturn         27532 non-null  uint8
#  48  manufacturer_subaru         27532 non-null  uint8
#  49  manufacturer_toyota         27532 non-null  uint8
#  50  manufacturer_volkswagen     27532 non-null  uint8
#  51  manufacturer_volvo          27532 non-null  uint8
#  52  manufacturer_ᴄhrysler       27532 non-null  uint8
#  53  size_compact                27532 non-null  uint8
#  54  size_fullsize               27532 non-null  uint8
#  55  size_midsize                27532 non-null  uint8
#  56  size_subcompact             27532 non-null  uint8
#  57  fuel_diesel                 27532 non-null  uint8
#  58  fuel_electric               27532 non-null  uint8
#  59  fuel_gas                    27532 non-null  uint8
#  60  fuel_hybrid                 27532 non-null  uint8
#  61  fuel_other                  27532 non-null  uint8
#  62  drive_4wd                   27532 non-null  uint8
#  63  drive_fwd                   27532 non-null  uint8
#  64  drive_rwd                   27532 non-null  uint8
#  65  type_SUV                    27532 non-null  uint8
#  66  type_bus                    27532 non-null  uint8
#  67  type_convertible            27532 non-null  uint8
#  68  type_coupe                  27532 non-null  uint8
#  69  type_hatchback              27532 non-null  uint8
#  70  type_mini-van               27532 non-null  uint8
#  71  type_offroad                27532 non-null  uint8
#  72  type_other                  27532 non-null  uint8
#  73  type_pickup                 27532 non-null  uint8
#  74  type_sedan                  27532 non-null  uint8
#  75  type_truck                  27532 non-null  uint8
#  76  type_van                    27532 non-null  uint8
#  77  type_wagon                  27532 non-null  uint8
#  78  title_status_clean          27532 non-null  uint8
#  79  title_status_lien           27532 non-null  uint8
#  80  title_status_missing        27532 non-null  uint8
#  81  title_status_parts only     27532 non-null  uint8
#  82  title_status_rebuilt        27532 non-null  uint8
#  83  title_status_salvage        27532 non-null  uint8
#  84  paint_color_black           27532 non-null  uint8
#  85  paint_color_blue            27532 non-null  uint8
#  86  paint_color_brown           27532 non-null  uint8
#  87  paint_color_custom          27532 non-null  uint8
#  88  paint_color_green           27532 non-null  uint8
#  89  paint_color_grey            27532 non-null  uint8
#  90  paint_color_orange          27532 non-null  uint8
#  91  paint_color_purple          27532 non-null  uint8
#  92  paint_color_red             27532 non-null  uint8
#  93  paint_color_silver          27532 non-null  uint8
#  94  paint_color_white           27532 non-null  uint8
#  95  paint_color_yellow          27532 non-null  uint8
#  96  transmission_automatic      27532 non-null  uint8
#  97  transmission_manual         27532 non-null  uint8
#  98  transmission_other          27532 non-null  uint8
# dtypes: float64(4), int32(2), int64(4), uint8(89)
# memory usage: 4.2 MB

# %%
cols = ["state_area", "state_pop"]

# %%
nu = 3
for i in range(2, nu):
    for c in cols:
        train[f"{c}{i}"] = train[c] ** i
        test[f"{c}{i}"] = test[c] ** i

# %%
train = train.query("year <= 2023 and odometer >= 0")
# test = test.query("year <= 2023 and odometer >= 0")
train.describe()
# Out:
#                  id        region          year     cylinders      odometer  \
# count  27263.000000  27263.000000  27263.000000  27263.000000  2.726300e+04
# mean   13767.439974    101.023989   2007.692660      5.691808  1.171515e+05
# std     7951.260409     77.947394     10.110576      1.509441  6.379211e+04
# min        0.000000      0.000000   1921.000000      3.000000  2.200000e+01
# 25%     6879.500000     40.000000   2005.000000      4.000000  7.950600e+04
# 50%    13772.000000     84.000000   2011.000000      6.000000  1.120460e+05
# 75%    20652.500000    147.000000   2014.000000      6.000000  1.513815e+05
# max    27531.000000    371.000000   2022.000000     12.000000  2.946000e+06
#
#               state         price      state_pd     state_area     state_pop  \
# count  27263.000000  27263.000000  27263.000000   23989.000000  2.398900e+04
# mean      20.756300  13455.268239    740.191137   82709.842636  2.926619e+07
# std       16.232529  10940.538436   1522.491695   74495.839943  5.746343e+07
# min        0.000000   1004.000000      1.000000      68.000000  4.890650e+05
# 25%        6.000000   5756.500000     96.000000   42774.000000  4.996464e+06
# 50%       17.000000   9207.000000    239.000000   65496.000000  1.042279e+07
# 75%       31.000000  19117.000000    740.049777  104093.000000  2.301495e+07
# max       51.000000  96818.000000   9856.000000  665384.000000  2.259081e+08
#
#        ...  paint_color_purple  paint_color_red  paint_color_silver  \
# count  ...        27263.000000     27263.000000        27263.000000
# mean   ...            0.000880         0.051462            0.156219
# std    ...            0.029658         0.220942            0.363070
# min    ...            0.000000         0.000000            0.000000
# 25%    ...            0.000000         0.000000            0.000000
# 50%    ...            0.000000         0.000000            0.000000
# 75%    ...            0.000000         0.000000            0.000000
# max    ...            1.000000         1.000000            1.000000
#
#        paint_color_white  paint_color_yellow  transmission_automatic  \
# count       27263.000000        27263.000000            27263.000000
# mean            0.131570            0.001100                0.744672
# std             0.338029            0.033155                0.436053
# min             0.000000            0.000000                0.000000
# 25%             0.000000            0.000000                0.000000
# 50%             0.000000            0.000000                1.000000
# 75%             0.000000            0.000000                1.000000
# max             1.000000            1.000000                1.000000
#
#        transmission_manual  transmission_other   state_area2    state_pop2
# count         27263.000000        27263.000000  2.398900e+04  2.398900e+04
# mean              0.223453            0.031875  1.239032e+10  4.158418e+15
# std               0.416567            0.175670  3.325702e+10  1.343564e+16
# min               0.000000            0.000000  4.624000e+03  2.391846e+11
# 25%               0.000000            0.000000  1.829615e+09  2.496465e+13
# 50%               0.000000            0.000000  4.289726e+09  1.086346e+14
# 75%               0.000000            0.000000  1.083535e+10  5.296879e+14
# max               1.000000            1.000000  4.427359e+11  5.103448e+16
#
# [8 rows x 101 columns]

# %%
import lightgbm as lgbm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error

# %%
test.shape
# Out:
# (27537, 100)

# %%
col = ["year", "odometer", "condition", "state_pd"]
col2 = ["region", "manufacturer", "condition", "cylinders", "fuel", "title_status", "transmission", "drive", "size", "type", "paint_color", "state"]
col += col2
# X = train[col]
X = train.drop(columns=["price", "id"])
test = test.drop(columns=["id"])
y = train["price"]

# %%
test.shape
# Out:
# (27537, 99)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
lgb_train = lgb.Dataset(X_train, y_train)
# ハイパーパラメータを設定
params = {
    'objective': 'regression',   # 目的関数: 回帰
    'metric': 'mse',             # 評価指標: 平均二乗誤差
    'boosting_type': 'gbdt',     # 勾配ブースティング
    'num_leaves': 31,            # ツリーの葉の数
    'learning_rate': 0.05,       # 学習率
}
# モデルを訓練
num_round = 560  # イテレーション数
model = lgb.train(params, lgb_train, num_round)
pred = model.predict(X_test)
score = mean_absolute_percentage_error(y_test, pred)
print(score*100)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001695 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1072
# [LightGBM] [Info] Number of data points in the train set: 18266, number of used features: 88
# [LightGBM] [Info] Start training from score 13379.011004
# 64.54713625825389

# %%
submit = pd.read_csv("submit_sample.csv", header=None)
submit.head()
# Out:
#        0             1
# 0  27532  18546.172992
# 1  27533   5899.888298
# 2  27534   6883.536308
# 3  27535  27638.250807
# 4  27536  13572.478035

# %%
pred = model.predict(test)
submit[1] = pred

# %%
submit.to_csv("submit_sample.csv", index=False, header=None)

# %%
pred
# Out:
# array([15200.42211518,  7233.34199844,  7731.8402472 , ...,
#        12961.48136902, 10355.62776304, 10069.12171361])
